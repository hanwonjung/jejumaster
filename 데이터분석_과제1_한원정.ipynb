# %% [markdown]
# <a href="https://colab.research.google.com/github/hanwonjung/jejumaster/blob/main/%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D_%EA%B3%BC%EC%A0%9C1_%ED%95%9C%EC%9B%90%EC%A0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **우리의 이웃은 누구인가**

# %% [markdown]
# 목적 : 우리나라에 입국한 외국인들의 수와 국적을 알아보고 현재 우리나라에 체류하고 있는 사람들에 대해서 다시금 생각해 본다.

# %%
PATH = './sample_data/'
FILE = '국적_체류자격별_외국인_입국자_월간__연간__202311021620.csv'

# %%
import pandas as pd
import matplotlib.pyplot as plt

file = PATH+FILE
#df = pd.read_csv(file, encoding = 'cp949') #cp949: 윈도우OS 기본 인코딩 포맷
df = pd.read_csv(file, encoding = 'utf-8')
df
# Out:
#         국적별 체류자격별       계      남자      여자
# 0        합계    총계  412948  229897  183050
# 1    아프가니스탄    총계     111      71      40
# 2       바레인    총계       7       1       6
# 3     방글라데시    총계    7283    6575     708
# 4        부탄    총계      16       6      10
# ..      ...   ...     ...     ...     ...
# 178  부르키나파소    총계       8       6       2
# 179     잠비아    총계      22      10      12
# 180     무국적    총계      40      16      24
# 181    국제연합    총계       8       5       3
# 182      미상    총계       9       5       4
#
# [183 rows x 5 columns]

# %%
df.columns
df
# Out:
#         국적별 체류자격별       계      남자      여자
# 0        합계    총계  412948  229897  183050
# 1    아프가니스탄    총계     111      71      40
# 2       바레인    총계       7       1       6
# 3     방글라데시    총계    7283    6575     708
# 4        부탄    총계      16       6      10
# ..      ...   ...     ...     ...     ...
# 178  부르키나파소    총계       8       6       2
# 179     잠비아    총계      22      10      12
# 180     무국적    총계      40      16      24
# 181    국제연합    총계       8       5       3
# 182      미상    총계       9       5       4
#
# [183 rows x 5 columns]

# %%
#합계 행 삭제
df = df[df.국적별 != '합계']
df
# Out:
#         국적별 체류자격별     계    남자   여자
# 1    아프가니스탄    총계   111    71   40
# 2       바레인    총계     7     1    6
# 3     방글라데시    총계  7283  6575  708
# 4        부탄    총계    16     6   10
# 5      브루나이    총계   147    39  108
# ..      ...   ...   ...   ...  ...
# 178  부르키나파소    총계     8     6    2
# 179     잠비아    총계    22    10   12
# 180     무국적    총계    40    16   24
# 181    국제연합    총계     8     5    3
# 182      미상    총계     9     5    4
#
# [182 rows x 5 columns]

# %%
#체류자 수로 정렬 (내림차순)
df_my_group = df.sort_values(by=['계'],ascending=False)
df_my_group
# Out:
#         국적별 체류자격별      계     남자     여자
# 9        중국    총계  95063  44207  50856
# 45      베트남    총계  51650  28030  23620
# 40       태국    총계  34744  13744  21000
# 44   우즈베키스탄    총계  22208  15060   7148
# 75       미국    총계  21464   8485  12978
# ..      ...   ...    ...    ...    ...
# 159    모리타니    총계      1      0      1
# 48      바하마    총계      1      1      0
# 61     그레나다    총계      1      1      0
# 125     나우루    총계      1      0      1
# 129      통가    총계      1      1      0
#
# [182 rows x 5 columns]

# %%
#2022년 상위30개 국적만 출력
df_my_group_100 = df_my_group.head(30)
df_my_group_100
# Out:
#           국적별 체류자격별      계     남자     여자
# 9          중국    총계  95063  44207  50856
# 45        베트남    총계  51650  28030  23620
# 40         태국    총계  34744  13744  21000
# 44     우즈베키스탄    총계  22208  15060   7148
# 75         미국    총계  21464   8485  12978
# 14      인도네시아    총계  16669  14671   1998
# 29         네팔    총계  15990  13525   2465
# 20      카자흐스탄    총계  15635   9519   6116
# 33        필리핀    총계  13612   9921   3691
# 112   러시아(연방)    총계  12324   6228   6096
# 7        캄보디아    총계  12004   8111   3893
# 28         몽골    총계  10788   5164   5624
# 6         미얀마    총계  10237   8686   1551
# 8        스리랑카    총계   7708   7301    407
# 3       방글라데시    총계   7283   6575    708
# 18         일본    총계   7177   1087   6090
# 53        캐나다    총계   5385   2186   3199
# 91        프랑스    총계   4613   1783   2830
# 13         인도    총계   4510   2952   1558
# 31       파키스탄    총계   3636   3112    524
# 93         독일    총계   3064   1151   1913
# 21     키르기스스탄    총계   3056   1988   1068
# ...

# %%
#2022년 하위10개 국적만 출력
df_my_group_100 = df_my_group.tail(10)
df_my_group_100
# Out:
#       국적별 체류자격별  계  남자  여자
# 153   레소토    총계  2   0   2
# 27    몰디브    총계  1   0   1
# 104    몰타    총계  1   0   1
# 142   지부티    총계  1   0   1
# 163  나미비아    총계  1   0   1
# 159  모리타니    총계  1   0   1
# 48    바하마    총계  1   1   0
# 61   그레나다    총계  1   1   0
# 125   나우루    총계  1   0   1
# 129    통가    총계  1   1   0

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 19 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 3s (3,532 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='cmb10')
plt.rc('font', family='NanumBarunGothic')

# %%
x = df_my_group_100['국적별']
y = df_my_group_100['계']


plt.figure(figsize = (15, 10))


plt.barh(x, y)
plt.title('우리의 이웃은 누구인가')
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# ...

# %%
#선그래프

x = df_my_group_100['국적별']
y = df_my_group_100['계']

plt.figure(figsize = (15, 5), facecolor = 'lavender')
plt.plot(x, y, color='mediumpurple', marker='o', linestyle='solid',
         linewidth=2, markersize=8, markerfacecolor='red')


plt.title('"우리의 이웃은 누구인가"', pad = 20,
          fontdict = {'size':30, 'color':'black', 'weight':'bold'})
plt.xlabel('국적', fontdict = {'size': 20, 'color': 'dimgray', 'weight': 'bold'})
plt.ylabel('계(명)', fontdict = {'size': 20, 'color': 'dimgray', 'weight': 'bold'}, labelpad = 20)
plt.xticks(rotation = 45)
plt.grid(True, axis = 'y', alpha = 0.5)

plt.show()

# %%
#혼합 그래프

import matplotlib.pyplot as plt
x = df_my_group_100['국적별']
y = df_my_group_100['계']

plt.figure(figsize = (15, 5), facecolor = 'lavender')
plt.bar(x, y, color = 'mediumpurple')
plt.plot(x, y, color='royalblue', marker='o',
         linewidth=2, markerfacecolor='red')

plt.title('"우리의 이웃은 누구인가"', pad = 20,
          fontdict = {'size':30, 'color':'black', 'weight':'bold'})
plt.xlabel('국적', fontdict = {'size': 20, 'color': 'dimgray', 'weight': 'bold'})
plt.ylabel('계(명)', fontdict = {'size': 20, 'color': 'dimgray', 'weight': 'bold'}, labelpad = 20)
plt.xticks(rotation = 45)
plt.grid(True, axis = 'y', alpha = 0.5)

plt.show()

# %% [markdown]
# 워드 크라우드

# %%
#라이브러리 설치
# !pip install wordcloud

# %% [markdown]
# 데이터 분석을 통한 정리 :
# 최근에 아는 지인의 동생분이 갑자기 조지아라는 나라로 이민을 갔다고 한다. 여행이나 이직도 아닌데 갑자기 새로운 나라에 대한 동경이 생겨서 이민을 신청했다고 해서 놀란 적이 있다. 친동생이 또한 10여년전에 공부를 위해서 독일에서 유학을 한 적이 있다. 한국에 들어오면서 독일에서 지내던 라트비아 친구와 가정이 함께 한국에서 생활할 수 있게 도와주었고 실제로 친정 부모님댁에서 5년정도 함께 살기도 했다. 한국말도 아예 할 수 없었던 그 가정의 두 남매가 한국생활에서 취업이나 학교 생활에서도 매우 잘 적응했는데 바로 그들이 영어를 구사하는 독일 국적을 가진 외국인이였기 때문이다. 외국인 특히 백인 사람이 많이 사는 곳이 아니였기 때문에 사람들의 호기심과 관심 그리고 친절도가 다른 나라 사람들 보다 높았다. 그러나 과연 그들이 선진국이 아닌 다른 나라에서 온 사람들이 였어도 많은 사람들의 관심을 받을 수 있었을까...
#  개인적으로 난민, 외국인 노동자, 북한이주민에 대한 관심도 많은 편이고 그들을 부족하지만 꾸준히 다양한 방법으로 후원하고 있는데 코로나 이후 사실 이들에 대한 나의 관심이나 사회의 관심이 더 줄어드는 것을 체감하게 되었다.
#  데이터를 통해서 알게 된 것은 아시아, 동남아 지역에서 온 사람들이 많을 것이라고 생각은 했지만 중국에서 온 사람들의 수가 압도적으로 많다는 것이 놀라웠다. 상위 30개 국의 리스트는 어느정도 예상한 나라들이 많았지만 하위 리스트를 보니 정말 한번도 들어보지 못한 나라들이 대부분이였다. 정말 우리나라에 내가 생각하고 들어보지 못한 국적을 가진 사람들이 함께 와서 살고 있다는 사실도 신기했다.
#   북한을 이탈해 온 학생들을 5년정도 수업한 적이 있는데 이때 중국 국적을 가진 사람들이 많았었는데 진짜 한족 뿐 아니라 북한에서 자랐지만 중국국적을 가지고 온 사람들이 저 데이터 안에 많이 포함 되어 있지는 않을까 하는 생각이 들었다.
#  데이터 분석을 통해서 막연하게나마 추측했던 나의 생각들이 수치화 되어 나타나니 내 옆에 살고 있지만 내가 한번도 이야기 나누지 못했던 나라의 이웃들이 많다는 것도 알게 되었다. 그들을 돕는 존재로 보는 것이 아니라  함께 한국 땅에서 즐겁고 행복한 삶을 누리는 이웃이 되고 싶다.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
font_path = '/usrdf_my_group_100/share/fonts/truetype/nanum/NanumGothicBold.ttf'
names = df_my_group_100['국적별']
counts = df_my_group_100['계']
data = dict(zip(names, counts))
data
wc = WordCloud(width = 1000, height = 600,
               background_color="black", font_path=font_path)
plt.imshow(wc.generate_from_frequencies(data))
plt.axis("off")
plt.show()

wc.to_file('./이웃_워드클라우드.png')
